# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
facturacion_tienda = tienda['Precio'].sum()
facturacion_tienda2 = tienda2['Precio'].sum()
facturacion_tienda3 = tienda3['Precio'].sum()
facturacion_tienda4 = tienda4['Precio'].sum()

# %%
print(f"La tienda 1 tiene {facturacion_tienda} de ingresos")
print(f"La tienda 2 tiene {facturacion_tienda2} de ingresos")
print(f"La tienda 3 tiene {facturacion_tienda3} de ingresos")
print(f"La tienda 4 tiene {facturacion_tienda4} de ingresos")
# Out:
# La tienda 1 tiene 1150880400.0 de ingresos
# La tienda 2 tiene 1116343500.0 de ingresos
# La tienda 3 tiene 1098019600.0 de ingresos
# La tienda 4 tiene 1038375700.0 de ingresos

# %% [markdown]
# # 2. Ventas por categoría

# %%
ventas_categorias_1 = tienda['Categoría del Producto'].value_counts()
ventas_categorias_2 = tienda2['Categoría del Producto'].value_counts()
ventas_categorias_3 = tienda3['Categoría del Producto'].value_counts()
ventas_categorias_4 = tienda4['Categoría del Producto'].value_counts()

# %%
ventas_categorias_1.sort_values(ascending=False)
# Out:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64

# %%
ventas_categorias_2.sort_values(ascending=False)
# Out:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64

# %%
ventas_categorias_3.sort_values(ascending=False)
# Out:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# Artículos para el hogar    177
# Name: count, dtype: int64

# %%
ventas_categorias_4.sort_values(ascending=False)
# Out:
# Categoría del Producto
# Muebles                    480
# Electrónicos               451
# Juguetes                   338
# Deportes y diversión       277
# Electrodomésticos          254
# Artículos para el hogar    201
# Libros                     187
# Instrumentos musicales     170
# Name: count, dtype: int64

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
calificacion_tienda_1 = tienda['Calificación'].mean()
calificacion_tienda_2 = tienda2['Calificación'].mean()
calificacion_tienda_3 = tienda3['Calificación'].mean()
calificacion_tienda_4 = tienda4['Calificación'].mean()

# %%
print(f"Calificacion para la tienda 1 es {round(calificacion_tienda_1,2)}")
print(f"Calificacion para la tienda 2 es {round(calificacion_tienda_2,2)}")
print(f"Calificacion para la tienda 3 es {round(calificacion_tienda_3,2)}")
print(f"Calificacion para la tienda 4 es {round(calificacion_tienda_4,2)}")
# Out:
# Calificacion para la tienda 1 es 3.98
# Calificacion para la tienda 2 es 4.04
# Calificacion para la tienda 3 es 4.05
# Calificacion para la tienda 4 es 4.0

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
producto_mas_vendido_1 = tienda['Producto'].value_counts(ascending=False)
producto_mas_vendido_2 = tienda2['Producto'].value_counts(ascending=False)
producto_mas_vendido_3 = tienda3['Producto'].value_counts(ascending=False)
producto_mas_vendido_4 = tienda4['Producto'].value_counts(ascending=False)

# %%
producto_mas_vendido_1.sort_values().plot(kind='barh', figsize= (10,8), color='red',xlabel= 'Cantidad')
# Out:
# <Axes: xlabel='Cantidad', ylabel='Producto'>

# %%
producto_mas_vendido_2.sort_values().plot(kind='barh', figsize= (10,8), color='red',xlabel= 'Cantidad')
# Out:
# <Axes: xlabel='Cantidad', ylabel='Producto'>

# %%
producto_mas_vendido_3.sort_values().plot(kind='barh', figsize= (10,8), color='red',xlabel= 'Cantidad')
# Out:
# <Axes: xlabel='Cantidad', ylabel='Producto'>

# %%
producto_mas_vendido_4.sort_values().plot(kind='barh', figsize= (10,8), color='red',xlabel= 'Cantidad')
# Out:
# <Axes: xlabel='Cantidad', ylabel='Producto'>

# %%
producto_mas_vendido_1.head(1) # producto mas vendido - tienda 1
# Out:
# Producto
# Microondas    60
# Name: count, dtype: int64

# %%
producto_mas_vendido_1.tail(1) # producto menos vendido - tienda 1
# Out:
# Producto
# Celular ABXY    33
# Name: count, dtype: int64

# %%
producto_mas_vendido_2.head(1) # producto mas vendido - tienda 2
# Out:
# Producto
# Iniciando en programación    65
# Name: count, dtype: int64

# %%
producto_mas_vendido_2.tail(1) # producto menos vendido - tienda 2
# Out:
# Producto
# Juego de mesa    32
# Name: count, dtype: int64

# %%
producto_mas_vendido_3.head(1) # producto mas vendido - tienda 3
# Out:
# Producto
# Kit de bancas    57
# Name: count, dtype: int64

# %%
producto_mas_vendido_3.tail(1) # producto menos vendido - tienda 3
# Out:
# Producto
# Bloques de construcción    35
# Name: count, dtype: int64

# %%
producto_mas_vendido_4.head(1) # producto mas vendido - tienda 4
# Out:
# Producto
# Cama box    62
# Name: count, dtype: int64

# %%
producto_mas_vendido_4.tail(1) # producto menos vendido - tienda 4
# Out:
# Producto
# Guitarra eléctrica    33
# Name: count, dtype: int64

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
costo_envio_tienda_1 = tienda['Costo de envío'].mean()
costo_envio_tienda_2 = tienda2['Costo de envío'].mean()
costo_envio_tienda_3 = tienda3['Costo de envío'].mean()
costo_envio_tienda_4 = tienda4['Costo de envío'].mean()

# %%
print(f"El costo de envio de la tienda 1 es {round(costo_envio_tienda_1,2)}")
print(f"El costo de envio de la tienda 2 es {round(costo_envio_tienda_2,2)}")
print(f"El costo de envio de la tienda 3 es {round(costo_envio_tienda_3,2)}")
print(f"El costo de envio de la tienda 4 es {round(costo_envio_tienda_4,2)}")
# Out:
# El costo de envio de la tienda 1 es 26018.61
# El costo de envio de la tienda 2 es 25216.24
# El costo de envio de la tienda 3 es 24805.68
# El costo de envio de la tienda 4 es 23459.46

# %%
import matplotlib.pyplot as plt

# %%
# el grafico muestra las las cantidades totales vendidas por todas las tiendas por categoria
ventas_categorias_total = ventas_categorias_1 + ventas_categorias_2 + ventas_categorias_3 + ventas_categorias_4

plt.figure(figsize=(12, 7))
ventas_categorias_total.sort_values(ascending=False).plot(kind='bar', color='skyblue')
plt.title('Total de Cantidades Vendidas por Categoría en Todas las Tiendas')
plt.xlabel('Categoría del Producto')
plt.ylabel('Cantidad Vendida')
plt.xticks(ha='right')
plt.tight_layout()
plt.show()

# %%
calificaciones_promedio = {
    'Tienda 1': round(calificacion_tienda_1, 2),
    'Tienda 2': round(calificacion_tienda_2, 2),
    'Tienda 3': round(calificacion_tienda_3, 2),
    'Tienda 4': round(calificacion_tienda_4, 2)
}

calificaciones_series = pd.Series(calificaciones_promedio)

plt.figure(figsize=(10, 6))
calificaciones_series.plot(kind='bar', color='lightgreen')
plt.title('Calificación Promedio por Tienda')
plt.xlabel('Tienda')
plt.ylabel('Calificación Promedio')
plt.ylim(0, 5)
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
producto_mas_vendido_1.nlargest(10).sort_values().plot(kind='barh', figsize= (10,8), color='red',xlabel= 'Cantidad') # me muestra los 10 productos mas vendido en la tienda 1
# Out:
# <Axes: xlabel='Cantidad', ylabel='Producto'>

# %% [markdown]
# # **Informe Final**

# %% [markdown]
# El análisis realizo sirvió para evaluar que tienda será venidad basada en criterios como los ingresos, ventas por categoría y calificación promedio por tienda.
# Se realizaron consultas que muestran los ingresos de cada tienda, también las ventas por categoría, productos más y menos vendidos por cada tienda y la calificación promedio por tienda.
# Ya realizado el análisis de los datos podemos observar que la tienda 4 es que genera menos ingresos, aunque cada tienda tiene la misma cantidad de registros vendidos, esta muestra una diferencia significativa con las demás tiendas, por otro lado mediante la calificación Promedio por tienda es la tercera tienda con la calificación mas baja, la tienda 1 es la última con ínfima diferencia pero esta tienda es la que genera mas ingresos.
# En los negocios el criterio que pesa más son los ingresos por ese motivo se recomienda vender la tienda 4.
